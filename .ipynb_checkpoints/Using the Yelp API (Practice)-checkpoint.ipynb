# %%
import json
with open (r"C:\Users\Bijan Emadi\.secret\yelp_api.json") as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# import the YelpAPI Class
from yelpapi import YelpAPI
# Create an instance with your key
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='Baltimore, MD,21202',
                                       term='Crab Cakes')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 433

# %%
import pandas as pd

# %%
biz = pd.DataFrame(search_results['businesses'])
biz.head(2)
# Out:
#                        id                                 alias  \
# 0  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
# 1  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
#
#                          name  \
# 0  Thames Street Oyster House
# 1           Faidley's Seafood
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/8j3ynZ...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/thames-street-oyster-...          2747
# 1  https://www.yelp.com/biz/faidleys-seafood-balt...          1195
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
#
#                                        coordinates transactions price  \
# 0   {'latitude': 39.28214, 'longitude': -76.59162}   [delivery]   $$$
# 1  {'latitude': 39.291696, 'longitude': -76.62224}   [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '1728 Thames St', 'address2': '',...  +14434497726
# 1  {'address1': '203 N Paca St', 'address2': '', ...  +14107274898
#
#     display_phone     distance
# 0  (443) 449-7726  2090.712792
# 1  (410) 727-4898  1349.560720

# %%
## total number of matching businesses
search_results['total']
# Out:
# 433

# %%
## how many businesses in our results
len(search_results['businesses'])
# Out:
# 20

# %%
# add offset to our original api call
search_results = yelp_api.search_query(location='Baltimore, MD,21202',
                                       term='Crab Cakes',
                                       offset = 20)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id                                 alias  \
# 0  s0LPuaTzR9euWzNT52o49Q  sugarbees-cafe-and-grill-baltimore-5
# 1  TPQmNAM2g1vmm2xCfhyEJw      pratt-street-ale-house-baltimore
#
#                       name                                          image_url  \
# 0  Sugarbee's Cafe & Grill  https://s3-media2.fl.yelpcdn.com/bphoto/wJdfsJ...
# 1   Pratt Street Ale House  https://s3-media4.fl.yelpcdn.com/bphoto/GHyW4Q...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/sugarbees-cafe-and-gr...            37
# 1      False  https://www.yelp.com/biz/pratt-street-ale-hous...           817
#
#                                           categories  rating  \
# 0  [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 1  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     3.5
#
#                                          coordinates        transactions  \
# 0     {'latitude': 39.29205, 'longitude': -76.61585}  [delivery, pickup]
# 1  {'latitude': 39.2865982055664, 'longitude': -7...  [delivery, pickup]
#
#   price                                           location         phone  \
# 0     $  {'address1': '222 N Charles St', 'address2': '...  +14104430475
# 1    $$  {'address1': '206 W Pratt St', 'address2': '',...  +14102448900
#
#     display_phone     distance
# 0  (410) 443-0475   840.660168
# 1  (410) 244-8900  1403.278532

# %%
## concatenate the previous results and new results. 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                                 alias  \
# 0  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
# 1  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
# 2  u65W69AhbjUlvJJBkEhGNQ        miss-shirleys-cafe-baltimore-9
#
#                          name  \
# 0  Thames Street Oyster House
# 1           Faidley's Seafood
# 2         Miss Shirley's Cafe
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/8j3ynZ...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/9FsOyV...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/thames-street-oyster-...          2747
# 1  https://www.yelp.com/biz/faidleys-seafood-balt...          1195
# 2  https://www.yelp.com/biz/miss-shirleys-cafe-ba...          2959
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 2  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
#
#                                          coordinates transactions price  \
# 0     {'latitude': 39.28214, 'longitude': -76.59162}   [delivery]   $$$
# 1    {'latitude': 39.291696, 'longitude': -76.62224}   [delivery]    $$
# 2  {'latitude': 39.2870995, 'longitude': -76.6053...   [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '1728 Thames St', 'address2': '',...  +14434497726
# 1  {'address1': '203 N Paca St', 'address2': '', ...  +14107274898
# 2  {'address1': '750 E Pratt St', 'address2': '',...  +14105285373
#
#     display_phone     distance
# 0  (443) 449-7726  2090.712792
# 1  (410) 727-4898  1349.560720
# 2  (410) 528-5373  1028.736468
#                         id                             alias  \
# 37  heDO_cYM7C-BXmh17sMR-Q  avenue-kitchen-and-bar-baltimore
# 38  pJuoa35eDPRXLf7kUbpMTg            the-choptank-baltimore
# 39  TL34QOmDmMtJmsabvPLErg      annabel-lee-tavern-baltimore
#
#                     name                                          image_url  \
# 37  Avenue Kitchen & Bar  https://s3-media2.fl.yelpcdn.com/bphoto/qzmlw6...
# 38          The Choptank  https://s3-media3.fl.yelpcdn.com/bphoto/0Mdtr7...
# 39    Annabel Lee Tavern  https://s3-media2.fl.yelpcdn.com/bphoto/dh6k0b...
#
#     is_closed                                                url  \
# 37      False  https://www.yelp.com/biz/avenue-kitchen-and-ba...
# 38      False  https://www.yelp.com/biz/the-choptank-baltimor...
# 39      False  https://www.yelp.com/biz/annabel-lee-tavern-ba...
#
#     review_count                                         categories  rating  \
# 37           311  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 38           207         [{'alias': 'seafood', 'title': 'Seafood'}]     4.0
# 39           611  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.5
#
#                                          coordinates  \
# 37  {'latitude': 39.330862, 'longitude': -76.631807}
# 38  {'latitude': 39.283338, 'longitude': -76.593321}
# 39    {'latitude': 39.28538, 'longitude': -76.56961}
#
#                                   transactions price  \
# 37  [restaurant_reservation, pickup, delivery]    $$
# 38                                          []   NaN
# 39  [restaurant_reservation, pickup, delivery]    $$
#
#                                              location         phone  \
# 37  {'address1': '911 W 36th St', 'address2': None...  +14439618515
# 38  {'address1': '1641 Aliceanna St', 'address2': ...  +14437073364
# 39  {'address1': '601 S Clinton St', 'address2': '...  +14105222929
#
#      display_phone     distance
# 37  (443) 961-8515  4380.308991
# 38  (443) 707-3364  1891.591150
# 39  (410) 522-2929  3485.045821
